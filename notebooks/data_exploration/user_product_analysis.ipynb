# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
df_sessions = pd.read_json(path_or_buf='../../data/raw/sessions.jsonl', lines=True)
df_users = pd.read_json(path_or_buf='../../data/raw/users.jsonl', lines=True)
df_products = pd.read_json(path_or_buf='../../data/raw/products.jsonl', lines=True)

# %%
df_users.head()
# Out:
#    user_id              name      city                   street
# 0      102     Aurelia Malon    Poznań  pl. Brzoskwiniowa 11/53
# 1      103     Mateusz Kobel    Poznań        al. Wrocławska 10
# 2      104    Radosław Ratka  Szczecin           pl. Nowa 89/04
# 3      105  Anastazja Oszust  Warszawa     ul. Częstochowska 80
# 4      106      Sylwia Nurek  Warszawa          al. Wiosenna 72

# %%
df_sessions.head()
# Out:
#    session_id           timestamp  user_id  product_id    event_type  \
# 0         124 2021-07-28 15:47:21      102        1283  VIEW_PRODUCT
# 1         124 2021-07-28 15:47:40      102        1283   BUY_PRODUCT
# 2         125 2021-09-12 16:43:16      102        1076  VIEW_PRODUCT
# 3         125 2021-09-12 16:46:24      102        1080  VIEW_PRODUCT
# 4         125 2021-09-12 16:48:08      102        1079  VIEW_PRODUCT
#
#    offered_discount  purchase_id
# 0                 5          NaN
# 1                 5      20001.0
# 2                 0          NaN
# 3                 0          NaN
# 4                 0          NaN

# %%
df_products.head()
# Out:
#    product_id                                    product_name  \
# 0        1001                   Telefon Siemens Gigaset DA310
# 1        1002                              Kyocera FS-1135MFP
# 2        1003                              Kyocera FS-3640MFP
# 3        1004                            Fallout 3 (Xbox 360)
# 4        1005  Szalone Króliki Na żywo i w kolorze (Xbox 360)
#
#                                        category_path    price
# 0          Telefony i akcesoria;Telefony stacjonarne    58.97
# 1  Komputery;Drukarki i skanery;Biurowe urządzeni...  2048.50
# 2  Komputery;Drukarki i skanery;Biurowe urządzeni...  7639.00
# 3          Gry i konsole;Gry na konsole;Gry Xbox 360    49.99
# 4          Gry i konsole;Gry na konsole;Gry Xbox 360    49.99

# %% [markdown]
# # Agregacja tabel

# %%
df = df_sessions.merge(df_products, left_on='product_id', right_on='product_id')
df = df.merge(df_users, left_on='user_id', right_on='user_id')
df.drop(columns=['product_name'], inplace=True)
df.head()
# Out:
#    session_id           timestamp  user_id  product_id    event_type  \
# 0         124 2021-07-28 15:47:21      102        1283  VIEW_PRODUCT
# 1         124 2021-07-28 15:47:40      102        1283   BUY_PRODUCT
# 2         139 2021-07-01 11:28:02      102        1283  VIEW_PRODUCT
# 3         139 2021-07-01 11:31:18      102        1283   BUY_PRODUCT
# 4         144 2021-03-19 13:55:04      102        1283  VIEW_PRODUCT
#
#    offered_discount  purchase_id  \
# 0                 5          NaN
# 1                 5      20001.0
# 2                 0          NaN
# 3                 0      20013.0
# 4                 0          NaN
#
#                                        category_path  price           name  \
# 0  Sprzęt RTV;Video;Telewizory i akcesoria;Okular...  99.99  Aurelia Malon
# 1  Sprzęt RTV;Video;Telewizory i akcesoria;Okular...  99.99  Aurelia Malon
# 2  Sprzęt RTV;Video;Telewizory i akcesoria;Okular...  99.99  Aurelia Malon
# 3  Sprzęt RTV;Video;Telewizory i akcesoria;Okular...  99.99  Aurelia Malon
# 4  Sprzęt RTV;Video;Telewizory i akcesoria;Okular...  99.99  Aurelia Malon
#
#      city                   street
# 0  Poznań  pl. Brzoskwiniowa 11/53
# 1  Poznań  pl. Brzoskwiniowa 11/53
# 2  Poznań  pl. Brzoskwiniowa 11/53
# 3  Poznań  pl. Brzoskwiniowa 11/53
# 4  Poznań  pl. Brzoskwiniowa 11/53

# %%
aggregation_functions = {
    'timestamp' : lambda t: [(t.max() - t.min()).seconds, t.min(), t.max()],
    'user_id' : 'first',
    'product_id' : 'unique',
    'event_type' : lambda e: 1 if len(e.unique()) > 1 else 0,
    'offered_discount' : 'first',
    'category_path' : 'unique',
    'price' : 'last',
    'city' : 'first'
}
main_df = df.groupby(df['session_id']).aggregate(aggregation_functions)
main_df.rename(columns={'event_type' : 'purchased'}, inplace=True)

# %%
timestamp_dict = [{'session_length' : x[0], 'session_start' : x[1], 'session_end' : x[2]} for x in main_df['timestamp']]
timestamp_df = pd.DataFrame(timestamp_dict)

# %%
main_df = pd.concat([main_df, timestamp_df], axis=1, join="inner")
main_df.drop(columns=['timestamp'], inplace=True)
main_df.index.name = 'session_id'
main_df = main_df[['user_id', 'product_id', 'offered_discount', 'category_path', 'price', 'city', 'session_length', 'session_start', 'session_end', 'purchased']]
main_df.head()
# Out:
#             user_id                                        product_id  \
# session_id
# 124             102                                            [1283]
# 125             102  [1076, 1080, 1079, 1003, 1002, 1075, 1078, 1077]
# 126             102                                      [1281, 1278]
# 127             102                                      [1281, 1278]
# 128             102              [1008, 1007, 1013, 1012, 1004, 1010]
#
#             offered_discount  \
# session_id
# 124                        5
# 125                        0
# 126                       15
# 127                        0
# 128                        0
#
#                                                 category_path    price  \
# session_id
# 124         [Sprzęt RTV;Video;Telewizory i akcesoria;Okula...    99.99
# 125         [Komputery;Drukarki i skanery;Biurowe urządzen...  3777.00
# 126         [Sprzęt RTV;Przenośne audio i video;Odtwarzacz...    78.90
# 127         [Sprzęt RTV;Przenośne audio i video;Odtwarzacz...    78.90
# 128               [Gry i konsole;Gry na konsole;Gry Xbox 360]    89.99
#
#               city  session_length       session_start         session_end  \
# session_id
# 124         Poznań             725 2021-08-26 22:27:52 2021-08-26 22:39:57
# 125         Poznań            1547 2021-03-08 08:14:24 2021-03-08 08:40:11
# 126         Poznań             347 2021-02-16 17:40:31 2021-02-16 17:46:18
# 127         Poznań             457 2021-03-13 06:48:13 2021-03-13 06:55:50
# 128         Poznań            1010 2021-04-18 21:02:01 2021-04-18 21:18:51
#
#             purchased
# session_id
# 124                 1
# 125                 1
# 126                 1
# 127                 1
# 128                 1

# %% [markdown]
# # Analiza danych

# %% [markdown]
# ## Wydane pieniądze przez użytkowników danych miast

# %%
plt.bar(np.sort(main_df['city'].unique()), main_df.groupby(main_df['city'])['price'].agg('sum'))
plt.title('Suma wydatków przez użytkowników danych miast')
plt.xlabel('Miasto')
plt.ylabel('Suma wydatków [PLN]')
# Out:
# Text(0, 0.5, 'Suma wydatków [PLN]')

# %% [markdown]
# ## Wydatki użytkowników pochodzących z danych miast w każdym tygodniu

# %%
fig, ax = plt.subplots(nrows=7, ncols=1, figsize=(25,25), sharex='row', sharey='col')

fig.text(0.5, 0.1, 'Tydzień', ha='center', va='center')
fig.text(0.1, 0.5, 'Wydatki [PLN]', ha='center', va='center', rotation='vertical')
for i, city in enumerate(main_df['city'].unique()):
    ax[i].plot(
        main_df.loc[(main_df['city'] == city) & (main_df['session_start'].dt.isocalendar().week != 53)].groupby(main_df.loc[main_df['city'] == city]['session_start'].dt.isocalendar().week).aggregate({'price': 'sum'}), label=f"Suma wydatków w tygodniu w mieście {city}"
    )
    mean_by_week = main_df.loc[(main_df['city'] == city) & (main_df['session_start'].dt.isocalendar().week != 53)]['price'].sum() / 43
    ax[i].plot(np.arange(1, 44), [mean_by_week]*43, label=f"Średnia wydatków na tydzień w mieście {city}")
    ax[i].set_title(city)
    ax[i].legend()
